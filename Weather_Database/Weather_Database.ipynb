# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
# The citipy module finds the nearest city to the latitude and longitude pair with a population of 500 or more.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 609

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(30)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sao filipe
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | padang
# Processing Record 4 of Set 1 | tuatapere
# Processing Record 5 of Set 1 | isangel
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | atar
# Processing Record 8 of Set 1 | marsh harbour
# Processing Record 9 of Set 1 | tabou
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | kavieng
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | pervomayskoye
# Processing Record 15 of Set 1 | coihaique
# Processing Record 16 of Set 1 | thompson
# Processing Record 17 of Set 1 | wawa
# Processing Record 18 of Set 1 | airai
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | winnemucca
# Processing Record 21 of Set 1 | sisimiut
# Processing Record 22 of Set 1 | kropotkin
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | tazovskiy
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | lima
# Processing Record 29 of Set 1 | saint george
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | alyangula
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | mackay
# Processing Record 35 of Set 1 | chulman
# Processing Record 36 of Set 1 | lata
# Processing Record 37 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | clyde river
# Processing Record 40 of Set 1 | buraydah
# Processing Record 41 of Set 1 | san patricio
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | vangaindrano
# Processing Record 44 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 1 | bar harbor
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | burica
# City not found. Skipping...
# Processing Record 48 of Set 1 | southbridge
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | touros
# Processing Record 1 of Set 2 | san quintin
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | khatanga
# Processing Record 4 of Set 2 | yerbogachen
# Processing Record 5 of Set 2 | hasaki
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | ushuaia
# Processing Record 8 of Set 2 | kawana waters
# City not found. Skipping...
# Processing Record 9 of Set 2 | sao joao da barra
# Processing Record 10 of Set 2 | marechal deodoro
# Processing Record 11 of Set 2 | yellowknife
# Processing Record 12 of Set 2 | kazminskoye
# City not found. Skipping...
# Processing Record 13 of Set 2 | moa
# Processing Record 14 of Set 2 | gilleleje
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | chuy
# Processing Record 17 of Set 2 | dongli
# Processing Record 18 of Set 2 | wembley
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | magadan
# Processing Record 21 of Set 2 | fairview
# Processing Record 22 of Set 2 | dingle
# Processing Record 23 of Set 2 | cabo san lucas
# Processing Record 24 of Set 2 | ahipara
# Processing Record 25 of Set 2 | faanui
# Processing Record 26 of Set 2 | canberra
# Processing Record 27 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | kamenka
# Processing Record 30 of Set 2 | caarapo
# Processing Record 31 of Set 2 | johnstown
# Processing Record 32 of Set 2 | torata
# Processing Record 33 of Set 2 | qaanaaq
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | ilulissat
# Processing Record 36 of Set 2 | hofn
# Processing Record 37 of Set 2 | mina
# Processing Record 38 of Set 2 | castro
# Processing Record 39 of Set 2 | honningsvag
# Processing Record 40 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 2 | charters towers
# Processing Record 42 of Set 2 | komatipoort
# Processing Record 43 of Set 2 | anadyr
# Processing Record 44 of Set 2 | port lincoln
# Processing Record 45 of Set 2 | shimoda
# Processing Record 46 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 2 | klaksvik
# Processing Record 48 of Set 2 | khandyga
# Processing Record 49 of Set 2 | praya
# Processing Record 50 of Set 2 | xining
# Processing Record 1 of Set 3 | rockport
# Processing Record 2 of Set 3 | gigmoto
# Processing Record 3 of Set 3 | simpang
# Processing Record 4 of Set 3 | flin flon
# Processing Record 5 of Set 3 | avarua
# Processing Record 6 of Set 3 | college
# Processing Record 7 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 8 of Set 3 | yeppoon
# Processing Record 9 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 3 | emerald
# Processing Record 11 of Set 3 | severo-kurilsk
# Processing Record 12 of Set 3 | kodiak
# Processing Record 13 of Set 3 | hambantota
# Processing Record 14 of Set 3 | port-gentil
# Processing Record 15 of Set 3 | saint-pierre
# Processing Record 16 of Set 3 | gawler
# Processing Record 17 of Set 3 | creel
# Processing Record 18 of Set 3 | lagoa nova
# Processing Record 19 of Set 3 | enid
# Processing Record 20 of Set 3 | paamiut
# Processing Record 21 of Set 3 | usinsk
# Processing Record 22 of Set 3 | butaritari
# Processing Record 23 of Set 3 | lompoc
# Processing Record 24 of Set 3 | hammerfest
# Processing Record 25 of Set 3 | hue
# Processing Record 26 of Set 3 | rocha
# Processing Record 27 of Set 3 | codrington
# Processing Record 28 of Set 3 | roma
# Processing Record 29 of Set 3 | samarinda
# Processing Record 30 of Set 3 | pisco
# Processing Record 31 of Set 3 | cabedelo
# Processing Record 32 of Set 3 | provideniya
# Processing Record 33 of Set 3 | nome
# Processing Record 34 of Set 3 | jamestown
# Processing Record 35 of Set 3 | leningradskiy
# Processing Record 36 of Set 3 | hami
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | campbeltown
# Processing Record 39 of Set 3 | quelimane
# Processing Record 40 of Set 3 | cidreira
# Processing Record 41 of Set 3 | deputatskiy
# Processing Record 42 of Set 3 | moron
# Processing Record 43 of Set 3 | presidente dutra
# Processing Record 44 of Set 3 | lagoa
# Processing Record 45 of Set 3 | ballina
# Processing Record 46 of Set 3 | skjervoy
# Processing Record 47 of Set 3 | honiara
# Processing Record 48 of Set 3 | sorland
# Processing Record 49 of Set 3 | mahebourg
# Processing Record 50 of Set 3 | souillac
# Processing Record 1 of Set 4 | port alfred
# Processing Record 2 of Set 4 | balabac
# Processing Record 3 of Set 4 | beringovskiy
# Processing Record 4 of Set 4 | xinzhi
# Processing Record 5 of Set 4 | susanville
# Processing Record 6 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 4 | puerto ayora
# Processing Record 8 of Set 4 | mutis
# Processing Record 9 of Set 4 | san juan
# Processing Record 10 of Set 4 | ankazobe
# Processing Record 11 of Set 4 | san jeronimo
# Processing Record 12 of Set 4 | roebourne
# Processing Record 13 of Set 4 | tiruchchendur
# Processing Record 14 of Set 4 | kysyl-syr
# Processing Record 15 of Set 4 | puro
# Processing Record 16 of Set 4 | shebunino
# Processing Record 17 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 4 | new norfolk
# Processing Record 19 of Set 4 | chicama
# Processing Record 20 of Set 4 | yasnaya polyana
# Processing Record 21 of Set 4 | rassvet
# Processing Record 22 of Set 4 | naifaru
# Processing Record 23 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 4 | harper
# Processing Record 25 of Set 4 | aljezur
# Processing Record 26 of Set 4 | guanica
# Processing Record 27 of Set 4 | nuuk
# Processing Record 28 of Set 4 | ixtapa
# Processing Record 29 of Set 4 | santa vitoria do palmar
# Processing Record 30 of Set 4 | necochea
# Processing Record 31 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 4 | tuktoyaktuk
# Processing Record 33 of Set 4 | nata
# Processing Record 34 of Set 4 | saldanha
# Processing Record 35 of Set 4 | kahului
# Processing Record 36 of Set 4 | salalah
# Processing Record 37 of Set 4 | merauke
# Processing Record 38 of Set 4 | iqaluit
# Processing Record 39 of Set 4 | taiyuan
# Processing Record 40 of Set 4 | calama
# Processing Record 41 of Set 4 | soe
# Processing Record 42 of Set 4 | lethem
# Processing Record 43 of Set 4 | esperance
# Processing Record 44 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 4 | snejbjerg
# Processing Record 46 of Set 4 | concepcion
# Processing Record 47 of Set 4 | pevek
# Processing Record 48 of Set 4 | torbay
# Processing Record 49 of Set 4 | tasiilaq
# Processing Record 50 of Set 4 | umba
# Processing Record 1 of Set 5 | ngaoundere
# Processing Record 2 of Set 5 | pangody
# Processing Record 3 of Set 5 | longyearbyen
# Processing Record 4 of Set 5 | acapulco
# Processing Record 5 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 5 | chokurdakh
# Processing Record 7 of Set 5 | abeche
# Processing Record 8 of Set 5 | inhambane
# Processing Record 9 of Set 5 | okhotsk
# Processing Record 10 of Set 5 | ancud
# Processing Record 11 of Set 5 | dolores
# Processing Record 12 of Set 5 | fortuna
# Processing Record 13 of Set 5 | kayerkan
# Processing Record 14 of Set 5 | mana
# Processing Record 15 of Set 5 | saint-augustin
# Processing Record 16 of Set 5 | takoradi
# Processing Record 17 of Set 5 | fuerte olimpo
# Processing Record 18 of Set 5 | moctezuma
# Processing Record 19 of Set 5 | chapais
# Processing Record 20 of Set 5 | sitka
# Processing Record 21 of Set 5 | kholodnyy
# Processing Record 22 of Set 5 | juchitan
# City not found. Skipping...
# Processing Record 23 of Set 5 | iraray
# Processing Record 24 of Set 5 | havoysund
# Processing Record 25 of Set 5 | constitucion
# Processing Record 26 of Set 5 | zyryanka
# Processing Record 27 of Set 5 | ketchikan
# Processing Record 28 of Set 5 | vostok
# Processing Record 29 of Set 5 | labuhan
# Processing Record 30 of Set 5 | carnarvon
# Processing Record 31 of Set 5 | nichinan
# Processing Record 32 of Set 5 | bahia honda
# Processing Record 33 of Set 5 | svetlyy
# Processing Record 34 of Set 5 | mocuba
# Processing Record 35 of Set 5 | hornepayne
# Processing Record 36 of Set 5 | bilibino
# Processing Record 37 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 5 | camalu
# Processing Record 39 of Set 5 | corumba
# Processing Record 40 of Set 5 | longhua
# Processing Record 41 of Set 5 | anchorage
# Processing Record 42 of Set 5 | veraval
# Processing Record 43 of Set 5 | lazaro cardenas
# Processing Record 44 of Set 5 | maceio
# Processing Record 45 of Set 5 | sao jose da coroa grande
# Processing Record 46 of Set 5 | aksu
# Processing Record 47 of Set 5 | anshun
# Processing Record 48 of Set 5 | flinders
# Processing Record 49 of Set 5 | bandarbeyla
# Processing Record 50 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 6 | richards bay
# Processing Record 2 of Set 6 | guanare
# Processing Record 3 of Set 6 | artyom
# Processing Record 4 of Set 6 | pailon
# Processing Record 5 of Set 6 | karratha
# Processing Record 6 of Set 6 | obo
# Processing Record 7 of Set 6 | bambous virieux
# Processing Record 8 of Set 6 | barra dos coqueiros
# Processing Record 9 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 6 | otradnoye
# Processing Record 11 of Set 6 | uyuni
# Processing Record 12 of Set 6 | aloleng
# Processing Record 13 of Set 6 | ulaangom
# Processing Record 14 of Set 6 | betsiamites
# Processing Record 15 of Set 6 | cherskiy
# Processing Record 16 of Set 6 | ouesso
# Processing Record 17 of Set 6 | baykit
# Processing Record 18 of Set 6 | tutoia
# Processing Record 19 of Set 6 | namie
# Processing Record 20 of Set 6 | udachnyy
# Processing Record 21 of Set 6 | orlik
# Processing Record 22 of Set 6 | mehamn
# Processing Record 23 of Set 6 | cape town
# Processing Record 24 of Set 6 | shuangcheng
# Processing Record 25 of Set 6 | greytown
# Processing Record 26 of Set 6 | san jose
# Processing Record 27 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 6 | aklavik
# Processing Record 29 of Set 6 | kaitangata
# Processing Record 30 of Set 6 | madingou
# Processing Record 31 of Set 6 | los llanos de aridane
# Processing Record 32 of Set 6 | komarikhinskiy
# Processing Record 33 of Set 6 | berea
# Processing Record 34 of Set 6 | victoria
# Processing Record 35 of Set 6 | pachperwa
# Processing Record 36 of Set 6 | weligama
# Processing Record 37 of Set 6 | boa vista
# Processing Record 38 of Set 6 | damavand
# Processing Record 39 of Set 6 | naze
# Processing Record 40 of Set 6 | yar-sale
# Processing Record 41 of Set 6 | hithadhoo
# Processing Record 42 of Set 6 | lorengau
# Processing Record 43 of Set 6 | grand gaube
# Processing Record 44 of Set 6 | laguna
# Processing Record 45 of Set 6 | tezu
# Processing Record 46 of Set 6 | saskylakh
# Processing Record 47 of Set 6 | onega
# Processing Record 48 of Set 6 | sindou
# Processing Record 49 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 6 | mahalapye
# Processing Record 1 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 7 | habay
# Processing Record 3 of Set 7 | ust-karsk
# Processing Record 4 of Set 7 | liuzhou
# Processing Record 5 of Set 7 | huarmey
# Processing Record 6 of Set 7 | aurora
# Processing Record 7 of Set 7 | katsuura
# Processing Record 8 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 7 | puerto escondido
# Processing Record 10 of Set 7 | itapua poty
# City not found. Skipping...
# Processing Record 11 of Set 7 | koboldo
# City not found. Skipping...
# Processing Record 12 of Set 7 | broken hill
# Processing Record 13 of Set 7 | tecoanapa
# Processing Record 14 of Set 7 | bonavista
# Processing Record 15 of Set 7 | buchanan
# Processing Record 16 of Set 7 | camopi
# Processing Record 17 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 18 of Set 7 | arlit
# Processing Record 19 of Set 7 | pinerovka
# Processing Record 20 of Set 7 | asau
# Processing Record 21 of Set 7 | caravelas
# Processing Record 22 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 23 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 7 | yenagoa
# Processing Record 25 of Set 7 | nguruka
# Processing Record 26 of Set 7 | adrasmon
# Processing Record 27 of Set 7 | la palma
# Processing Record 28 of Set 7 | olafsvik
# Processing Record 29 of Set 7 | fomboni
# Processing Record 30 of Set 7 | east london
# Processing Record 31 of Set 7 | comodoro rivadavia
# Processing Record 32 of Set 7 | kasongo-lunda
# Processing Record 33 of Set 7 | abu samrah
# Processing Record 34 of Set 7 | walvis bay
# Processing Record 35 of Set 7 | shenjiamen
# Processing Record 36 of Set 7 | igrim
# Processing Record 37 of Set 7 | lebu
# Processing Record 38 of Set 7 | dedougou
# Processing Record 39 of Set 7 | cap malheureux
# Processing Record 40 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 41 of Set 7 | vicksburg
# Processing Record 42 of Set 7 | soyo
# Processing Record 43 of Set 7 | zabid
# Processing Record 44 of Set 7 | bubaque
# Processing Record 45 of Set 7 | muros
# Processing Record 46 of Set 7 | salinopolis
# Processing Record 47 of Set 7 | sambava
# Processing Record 48 of Set 7 | berlevag
# Processing Record 49 of Set 7 | guerrero negro
# Processing Record 50 of Set 7 | haines junction
# Processing Record 1 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 2 of Set 8 | swan hill
# Processing Record 3 of Set 8 | carutapera
# Processing Record 4 of Set 8 | werda
# Processing Record 5 of Set 8 | oranjemund
# Processing Record 6 of Set 8 | lagos
# Processing Record 7 of Set 8 | bereda
# Processing Record 8 of Set 8 | pangobilian
# Processing Record 9 of Set 8 | shangzhi
# Processing Record 10 of Set 8 | tandil
# Processing Record 11 of Set 8 | ambilobe
# Processing Record 12 of Set 8 | norman wells
# Processing Record 13 of Set 8 | bulungu
# Processing Record 14 of Set 8 | tucuma
# Processing Record 15 of Set 8 | vardo
# Processing Record 16 of Set 8 | ostrovnoy
# Processing Record 17 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 8 | khani
# Processing Record 19 of Set 8 | zolotinka
# City not found. Skipping...
# Processing Record 20 of Set 8 | gueret
# Processing Record 21 of Set 8 | vestmannaeyjar
# Processing Record 22 of Set 8 | phuket
# Processing Record 23 of Set 8 | riyadh
# Processing Record 24 of Set 8 | kralendijk
# Processing Record 25 of Set 8 | taree
# Processing Record 26 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 27 of Set 8 | antofagasta
# Processing Record 28 of Set 8 | le pont-de-claix
# Processing Record 29 of Set 8 | peniche
# Processing Record 30 of Set 8 | husavik
# Processing Record 31 of Set 8 | oussouye
# Processing Record 32 of Set 8 | auki
# Processing Record 33 of Set 8 | teguise
# Processing Record 34 of Set 8 | santa isabel
# Processing Record 35 of Set 8 | namibe
# Processing Record 36 of Set 8 | iroquois falls
# Processing Record 37 of Set 8 | sur
# Processing Record 38 of Set 8 | yebaishou
# Processing Record 39 of Set 8 | san policarpo
# Processing Record 40 of Set 8 | mount gambier
# Processing Record 41 of Set 8 | gorom-gorom
# Processing Record 42 of Set 8 | gucheng
# Processing Record 43 of Set 8 | isparta
# Processing Record 44 of Set 8 | la ronge
# Processing Record 45 of Set 8 | itambe
# Processing Record 46 of Set 8 | zhanaozen
# Processing Record 47 of Set 8 | gladstone
# Processing Record 48 of Set 8 | neyshabur
# Processing Record 49 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 50 of Set 8 | vila franca do campo
# Processing Record 1 of Set 9 | reyes
# Processing Record 2 of Set 9 | margate
# Processing Record 3 of Set 9 | fuyu
# Processing Record 4 of Set 9 | sinazongwe
# Processing Record 5 of Set 9 | lavrentiya
# Processing Record 6 of Set 9 | northam
# Processing Record 7 of Set 9 | linchuan
# City not found. Skipping...
# Processing Record 8 of Set 9 | pori
# Processing Record 9 of Set 9 | morehead
# Processing Record 10 of Set 9 | narsaq
# Processing Record 11 of Set 9 | yulara
# Processing Record 12 of Set 9 | sept-iles
# Processing Record 13 of Set 9 | soria
# Processing Record 14 of Set 9 | chaochou
# City not found. Skipping...
# Processing Record 15 of Set 9 | kutulik
# Processing Record 16 of Set 9 | evensk
# Processing Record 17 of Set 9 | dwarka
# Processing Record 18 of Set 9 | nioaque
# Processing Record 19 of Set 9 | manzanillo
# Processing Record 20 of Set 9 | tobane
# Processing Record 21 of Set 9 | damietta
# Processing Record 22 of Set 9 | plettenberg bay
# Processing Record 23 of Set 9 | kenai
# Processing Record 24 of Set 9 | caldwell
# Processing Record 25 of Set 9 | morwell
# Processing Record 26 of Set 9 | aquin
# Processing Record 27 of Set 9 | srednekolymsk
# Processing Record 28 of Set 9 | bartica
# Processing Record 29 of Set 9 | bengkulu
# Processing Record 30 of Set 9 | opunake
# Processing Record 31 of Set 9 | talnakh
# Processing Record 32 of Set 9 | druskininkai
# Processing Record 33 of Set 9 | nagato
# Processing Record 34 of Set 9 | cacoal
# Processing Record 35 of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 36 of Set 9 | feldru
# Processing Record 37 of Set 9 | karkal
# Processing Record 38 of Set 9 | fort abbas
# Processing Record 39 of Set 9 | garmsar
# Processing Record 40 of Set 9 | baillif
# Processing Record 41 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 9 | hamilton
# Processing Record 43 of Set 9 | nicoya
# Processing Record 44 of Set 9 | pavlogradka
# Processing Record 45 of Set 9 | havelock
# Processing Record 46 of Set 9 | burkhala
# City not found. Skipping...
# Processing Record 47 of Set 9 | borogontsy
# Processing Record 48 of Set 9 | kailua
# Processing Record 49 of Set 9 | upernavik
# Processing Record 50 of Set 9 | kudahuvadhoo
# Processing Record 1 of Set 10 | ponta do sol
# Processing Record 2 of Set 10 | spitsevka
# Processing Record 3 of Set 10 | kununurra
# Processing Record 4 of Set 10 | inuvik
# Processing Record 5 of Set 10 | najran
# Processing Record 6 of Set 10 | quesnel
# Processing Record 7 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 10 | korla
# Processing Record 9 of Set 10 | cayenne
# Processing Record 10 of Set 10 | sibolga
# Processing Record 11 of Set 10 | rorvik
# Processing Record 12 of Set 10 | la asuncion
# Processing Record 13 of Set 10 | tiksi
# Processing Record 14 of Set 10 | riverton
# Processing Record 15 of Set 10 | alice springs
# Processing Record 16 of Set 10 | nabire
# Processing Record 17 of Set 10 | yarmouth
# Processing Record 18 of Set 10 | vengerovo
# Processing Record 19 of Set 10 | kirovskiy
# Processing Record 20 of Set 10 | akonolinga
# Processing Record 21 of Set 10 | kingman
# Processing Record 22 of Set 10 | henties bay
# Processing Record 23 of Set 10 | saint anthony
# Processing Record 24 of Set 10 | oxford
# Processing Record 25 of Set 10 | maragogi
# Processing Record 26 of Set 10 | oktyabrskoye
# Processing Record 27 of Set 10 | benguela
# Processing Record 28 of Set 10 | layou
# Processing Record 29 of Set 10 | chifeng
# Processing Record 30 of Set 10 | nogliki
# Processing Record 31 of Set 10 | genhe
# Processing Record 32 of Set 10 | knysna
# Processing Record 33 of Set 10 | taltal
# Processing Record 34 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 10 | kirakira
# Processing Record 36 of Set 10 | saquarema
# Processing Record 37 of Set 10 | saint-francois
# Processing Record 38 of Set 10 | tabas
# Processing Record 39 of Set 10 | kloulklubed
# Processing Record 40 of Set 10 | sosnovo-ozerskoye
# Processing Record 41 of Set 10 | voyvozh
# Processing Record 42 of Set 10 | rahimatpur
# Processing Record 43 of Set 10 | chany
# Processing Record 44 of Set 10 | aden
# Processing Record 45 of Set 10 | coahuayana
# Processing Record 46 of Set 10 | norsup
# Processing Record 47 of Set 10 | sergeyevka
# Processing Record 48 of Set 10 | presidencia roque saenz pena
# Processing Record 49 of Set 10 | kilindoni
# Processing Record 50 of Set 10 | ransang
# Processing Record 1 of Set 11 | prattville
# Processing Record 2 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 3 of Set 11 | monte patria
# Processing Record 4 of Set 11 | awbari
# Processing Record 5 of Set 11 | alta floresta
# Processing Record 6 of Set 11 | atocha
# Processing Record 7 of Set 11 | lubao
# Processing Record 8 of Set 11 | grand-santi
# Processing Record 9 of Set 11 | sterlitamak
# Processing Record 10 of Set 11 | daru
# Processing Record 11 of Set 11 | key west
# Processing Record 12 of Set 11 | tubigan
# Processing Record 13 of Set 11 | nadym
# Processing Record 14 of Set 11 | flores
# Processing Record 15 of Set 11 | gamba
# Processing Record 16 of Set 11 | kutum
# Processing Record 17 of Set 11 | kayes
# Processing Record 18 of Set 11 | acajutla
# Processing Record 19 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 11 | port hueneme
# Processing Record 21 of Set 11 | kruisfontein
# Processing Record 22 of Set 11 | kombissiri
# Processing Record 23 of Set 11 | ocean city
# Processing Record 24 of Set 11 | oriximina
# Processing Record 25 of Set 11 | puerto del rosario
# Processing Record 26 of Set 11 | sungaipenuh
# Processing Record 27 of Set 11 | westport
# Processing Record 28 of Set 11 | quatre cocos
# Processing Record 29 of Set 11 | adrar
# Processing Record 30 of Set 11 | gat
# Processing Record 31 of Set 11 | goiatuba
# Processing Record 32 of Set 11 | ponnani
# Processing Record 33 of Set 11 | algeciras
# Processing Record 34 of Set 11 | moindou
# Processing Record 35 of Set 11 | keti bandar
# Processing Record 36 of Set 11 | sokoto
# Processing Record 37 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 11 | biak
# Processing Record 39 of Set 11 | puqi
# Processing Record 40 of Set 11 | el faiyum
# City not found. Skipping...
# Processing Record 41 of Set 11 | rawson
# Processing Record 42 of Set 11 | binzhou
# Processing Record 43 of Set 11 | maryborough
# Processing Record 44 of Set 11 | contai
# Processing Record 45 of Set 11 | ishigaki
# Processing Record 46 of Set 11 | beira
# Processing Record 47 of Set 11 | fairlie
# Processing Record 48 of Set 11 | dunedin
# Processing Record 49 of Set 11 | praia da vitoria
# Processing Record 50 of Set 11 | solnechnyy
# Processing Record 1 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 12 | santa lucia
# Processing Record 3 of Set 12 | piet retief
# Processing Record 4 of Set 12 | matera
# Processing Record 5 of Set 12 | nanortalik
# Processing Record 6 of Set 12 | ribeira brava
# Processing Record 7 of Set 12 | lahaina
# Processing Record 8 of Set 12 | mwense
# Processing Record 9 of Set 12 | verkhnyaya inta
# Processing Record 10 of Set 12 | greenfield
# Processing Record 11 of Set 12 | buenos aires
# Processing Record 12 of Set 12 | san blas
# Processing Record 13 of Set 12 | dali
# Processing Record 14 of Set 12 | san carlos de bariloche
# Processing Record 15 of Set 12 | komsomolskiy
# Processing Record 16 of Set 12 | kariba
# Processing Record 17 of Set 12 | nalut
# Processing Record 18 of Set 12 | dukat
# Processing Record 19 of Set 12 | diamantino
# Processing Record 20 of Set 12 | bathsheba
# Processing Record 21 of Set 12 | jaffna
# Processing Record 22 of Set 12 | cocula
# Processing Record 23 of Set 12 | didao
# Processing Record 24 of Set 12 | taoudenni
# Processing Record 25 of Set 12 | sal rei
# Processing Record 26 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 12 | san vicente
# Processing Record 28 of Set 12 | ipixuna
# Processing Record 29 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 30 of Set 12 | mangrol
# Processing Record 31 of Set 12 | leua
# Processing Record 32 of Set 12 | zhangjiakou
# Processing Record 33 of Set 12 | poronaysk
# Processing Record 34 of Set 12 | livno
# Processing Record 35 of Set 12 | luwuk
# Processing Record 36 of Set 12 | geraldton
# Processing Record 37 of Set 12 | gvardeysk
# Processing Record 38 of Set 12 | andenes
# Processing Record 39 of Set 12 | tahe
# Processing Record 40 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 41 of Set 12 | ozernovskiy
# Processing Record 42 of Set 12 | zhigansk
# Processing Record 43 of Set 12 | mbandaka
# Processing Record 44 of Set 12 | aksha
# Processing Record 45 of Set 12 | okandja
# City not found. Skipping...
# Processing Record 46 of Set 12 | faya
# Processing Record 47 of Set 12 | aswan
# Processing Record 48 of Set 12 | mengyin
# Processing Record 49 of Set 12 | agadir
# Processing Record 50 of Set 12 | ovalle
# Processing Record 1 of Set 13 | kargopol
# Processing Record 2 of Set 13 | brigantine
# Processing Record 3 of Set 13 | pangnirtung
# Processing Record 4 of Set 13 | edd
# Processing Record 5 of Set 13 | nishihara
# Processing Record 6 of Set 13 | izobilnyy
# Processing Record 7 of Set 13 | butterworth
# Processing Record 8 of Set 13 | cravo norte
# Processing Record 9 of Set 13 | marau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Do we have at least 500 cities?

len(city_data)
# Out:
# 558

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Sao Filipe  14.8961  -24.4956     77.23        88          68
# 1         Atuona  -9.8000 -139.0333     76.95        77           2
# 2         Padang  -0.9492  100.3543     86.05        64          85
# 3      Tuatapere -46.1333  167.6833     46.04        62          21
# 4        Isangel -19.5500  169.2667     77.11        57          75
# 5     Bredasdorp -34.5322   20.0403     52.11        93         100
# 6           Atar  20.5169  -13.0499     89.47        16         100
# 7  Marsh Harbour  26.5412  -77.0636     82.27        74           1
# 8          Tabou   4.4230   -7.3528     73.69        82          72
# 9   Punta Arenas -53.1500  -70.9167     32.11        93           0
#
#    Wind Speed      Description Country                 Date
# 0        8.86    broken clouds      CV  2022-08-11 04:28:00
# 1       20.13        clear sky      PF  2022-08-11 04:28:01
# 2        4.83  overcast clouds      ID  2022-08-11 04:27:23
# 3        4.25       few clouds      NZ  2022-08-11 04:28:01
# 4       11.50    broken clouds      VU  2022-08-11 04:23:38
# 5        4.76  overcast clouds      ZA  2022-08-11 04:28:01
# 6       10.42  overcast clouds      MR  2022-08-11 04:28:02
# 7       11.95        clear sky      BS  2022-08-11 04:28:02
# 8        6.26    broken clouds      CI  2022-08-11 04:28:03
# 9        5.75        clear sky      CL  2022-08-11 04:28:03

# %%
# assign a new column order that makes more sense

new_column_order = ["City","Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0  Sao Filipe      CV  2022-08-11 04:28:00  14.8961  -24.4956     77.23
# 1      Atuona      PF  2022-08-11 04:28:01  -9.8000 -139.0333     76.95
# 2      Padang      ID  2022-08-11 04:27:23  -0.9492  100.3543     86.05
# 3   Tuatapere      NZ  2022-08-11 04:28:01 -46.1333  167.6833     46.04
# 4     Isangel      VU  2022-08-11 04:23:38 -19.5500  169.2667     77.11
#
#    Humidity  Cloudiness  Wind Speed      Description
# 0        88          68        8.86    broken clouds
# 1        77           2       20.13        clear sky
# 2        64          85        4.83  overcast clouds
# 3        62          21        4.25       few clouds
# 4        57          75       11.50    broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
